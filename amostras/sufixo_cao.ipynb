# %%
nomes = set()

with open('nomes.txt', encoding='ascii') as fp:
    for line in fp:
        parts = line.strip().split()
        for part in parts:
            if part.endswith('cao'):
                nomes.add(part)

for nome in sorted(nomes):
    print(nome)
# Out:
# Acencao
# Adoracao
# Annunciacao
# Anuciacao
# Anunciacao
# Ascencao
# Assencao
# Assucao
# Assumpcao
# Assuncao
# Assunpcao
# Assupcao
# Balcao
# Bulcao
# Cacao
# Cansancao
# Cascao
# Ccnceicao
# Comceicao
# Concecao
# Conceicao
# Coneicao
# Consolacao
# Coracao
# Corcao
# Dascencao
# Dassumpcao
# Dassuncao
# Dincao
# Donacao
# Encarnacao
# Exaltacao
# Facao
# Falcao
# Fracao
# Fraccao
# Francao
# Franciscao
# Funcao
# Garcao
# Incao
# Invencao
# Ivencao
# Jacao
# Lorencao
# Loucao
# Lourencao
# Macao
# Machicao
# Marcao
# Molicao
# Moncao
# Nacao
# Nincao
# Patracao
# Picao
# Povoacao
# Presentacao
# Purificacao
# Rascao
# Reicao
# Rencao
# Ressureicao
# Ressurreicao
# Rincao
# Sancao
# Siscao
# Visitacao
# Vulcao
# Zucao
